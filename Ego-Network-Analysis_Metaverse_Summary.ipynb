# %% [markdown]
# # 메타버스 플랫폼의 유형별 사용자 만족 및 불만족 요인에 관한 연구: 온라인 리뷰 기반 LDA 토픽 모델링 및 에고 네트워크 분석 방법을 중심으로
# ### A Study on Determinants Affecting User’s Satisfaction and Dissatisfaction of The Type of Metaverse platform : Based on LDA Topic Modeling and Ego Network Analysis Method Using Online Review
# #### 👨‍💻 단국대학교 대학원 데이터지식서비스공학과 이기백
#
# Last Updated @2023-12-02

# %% [markdown]
# # 연구 목적

# %% [markdown]
# - 본 연구에서는 유형별로 메타버스 플랫폼을 구분한 뒤 온라인 리뷰를 기반으로 LDA 토픽모델링 및 에고 네트워크 	분석을 실시하여 메타버스 플랫폼의 유형별 만족 및 불만족 요인을 도출하는 것을 목표로 한다.

# %% [markdown]
# # 연구 절차
# ![image2.png](attachment:image2.png)

# %% [markdown]
# # 연구 결과(일부 발췌)_에고 네트워크 그래프
#
# 연구목적에 대한 답을 구하기 위해 LDA 토픽모델링을 통해 도출된 요인들의 영향력을 바탕으로 분석 결과를 아래와 같이 시각화하였다.
#
# 소셜형(Zepeto) / 거래형(Upland) / 협업형(MetaWorkplace) 유형별 메타버스 플랫폼의 사용자 만족 및 불만족 요인을 도출하고 비교 분석을 수행한 본 연구의 이론적, 실무적 시사점은 다음과 같다.
#
# - 첫째, 메타버스 유형에 관계없이 메타버스 플랫폼 사용자의 공통적인 불만족 요인은 Update, Connection, Email임을 확인하였다. 이 결과는, 관련 산업에 진입하거나, 시장을 선점하고자 하는 기업은 반드시 계정 접속 관련 이메일 인증 오류 문제와 업데이트로 인한 버그, 접속 지연 등 시스템 품질과 관련된 문제를 고려해야 함을 의미한다.
#
#
# - 둘째, 소셜형 메타버스 플랫폼의 리뷰 분석 결과 온라인 머니(zem)는 사용자 만족 및 불만족의 공통적 요소라는 점은 선행연구(이하경, 2022)의 결과를 지지한다. 이러한 결과를 통해 소셜형 메타버스 플랫폼에서 온라인 머니를 통해 구입한 아이템으로 아바타를 꾸미는 서비스에 만족함을 의미한다. 반면 리뷰 분석 결과 온라인 머니의 가격과 관련된 불만족 요인과 18세 이하 사용자가 71%인 제페토(박지윤, 2022)의 특성을 고려해야 한다는 것을 알 수 있다.
#
#
# - 셋째, 거래형 메타버스 플랫폼의 리뷰 분석 결과 이메일(email), 로그인(login) 요인이 사용자 불만족에 가장 높은 비율(0.450)을 차지한다. 이 결과를 통해 거래형 메타버스 플랫폼의 특성상 사용자 계정 보안 및 로그인 과정에서 발생하는 문제는 자산의 손실과 사용자 불만으로 직결되는 문제라고 해석할 수 있다. 따라서 관련 산업에 진입하고자 하는 기업은 사용자의 계정 관련 보안 및 로그인 관련 문제를 고려해야 함을 알 수 있다.
#
#
# - 넷째, 협업형 메타버스 플랫폼의 리뷰 분석 결과 알림(notification)은 사용자 만족 및 불만족의 공통적인 요소이며, 불만족 리뷰 중 가장 높은 비율(0.114)을 차지한다. 특히 불필요한 푸쉬 알림(0.222), 이메일 알림(0.234)이 정상적으로 작동하지 않는 문제가 사용자 불만과 직결되는 것으로 해석할 수 있다. 협업형 메타버스 플랫폼의 특성상 알림 기능이 정상적으로 작동하지 않는 것은 치명적인 단점으로 관련 산업에 진입하고자 하는 기업은 알림 오작동 관련 문제를 고려해야 함을 의미한다.
#
# ![image-7.png](attachment:image-7.png)

# %% [markdown]
# # 연구 결과(일부 발췌)_구조적 공백 분석
# ![image3-2.png](attachment:image3-2.png)

# %% [markdown]
# # 연구의 한계점
#
# - 본 연구는 수집된 데이터 특성에 기인한 2가지 한계점이 존재한다.
#
#
# - 첫째, 본 연구에서 수집한 사용자 리뷰 데이터는 패널 데이터가 아니었기 때문에 시간 고정 효과를 완전히 반영하지 못 하였다는 한계가 있다. 따라서 향후 연구에서 패널 데이터를 추가할 경우 사용자 경험 요인과 만족도의 동적 관계를 추정할 수 있다.
#
#
# - 둘째, 본 연구는 데이터 수집을 위하여 Google Play Store에 등록된 모바일 메타버스 플랫폼을 대상으로 연구했다는 한계점이 있다. 이로 인해 자체 서비스를 제공하는 메타버스 플랫폼은 초기 연구 대상 설정 과정에서 제외하였다.
